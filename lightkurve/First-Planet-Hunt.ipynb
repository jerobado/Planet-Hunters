# %%
import lightkurve as lk

# %%
# test search
result = lk.search_targetpixelfile('Pi Mensae', mission='TESS', sector=1)
# Out:
# gzip was not found on your system! You should solve this issue for astroquery.eso to be at its best!
# On POSIX system: make sure gzip is installed and in your path!On Windows: same for 7-zip (http://www.7-zip.org)!

# %%
result
# Out:
# SearchResult containing 1 data products.
#
#  #   observation  target_name                     productFilename                     distance
# --- ------------- ----------- ------------------------------------------------------- --------
#   0 TESS Sector 1   261136679 tess2018206045859-s0001-0000000261136679-0120-s_tp.fits      0.0

# %%
# searching in TOI
result = lk.search_targetpixelfile('Qatar-1b', mission='TESS', sector=17)

# %%
result
# Out:
# SearchResult containing 1 data products.
#
#  #   observation   target_name                     productFilename                     distance
# --- -------------- ----------- ------------------------------------------------------- --------
#   0 TESS Sector 17   236887394 tess2019279210107-s0017-0000000236887394-0161-s_tp.fits      0.0

# %%
# download result
tpf = result.download()

# %%
dir(tpf)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_aperture_photometry',
#  '_estimate_centroids_via_moments',
#  '_estimate_centroids_via_quadratic',
#  '_hdu',
#  '_parse_aperture_mask',
#  'astropy_time',
#  'background_mask',
#  'cadenceno',
#  'camera',
#  'ccd',
#  'column',
#  'create_threshold_mask',
#  'cutout',
#  'dec',
#  'estimate_centroids',
#  'extract_aperture_photometry',
#  'flux',
#  'flux_bkg',
#  'flux_bkg_err',
#  'flux_err',
#  'get_bkg_lightcurve',
#  'get_coordinates',
#  'get_keyword',
#  'hdu',
#  'header',
#  'interact',
#  'interact_sky',
#  'mission',
# ...

# %%
tpf.targetid
# Out:
# 236887394

# %%
tpf.ra, tpf.dec
# Out:
# (303.381740156372, 65.1620808095522)

# %%
tpf.plot()

# %%
lc = tpf.to_lightcurve(aperture_mask=tpf.pipeline_mask)

# %%
lc.plot()

# %%
lc.time.shape
# Out:
# (16945,)

# %%
flatten_lc = lc.flatten(window_length=847)
flatten_lc.errorbar()

# %%
lc.scatter()

# %%
folded_lc = lc.fold(period=2, t0=1775.)
folded_lc.plot()

# %%
scatter_lc = lc.scatter()

# %%
scatter_lc.fold(period=1.42, t0=1775.)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-7091ba5aa00c> in <module>
# ----> 1 scatter_lc.fold(period=1.42, t0=1775.)
#
# AttributeError: 'AxesSubplot' object has no attribute 'fold'

# %%
lc
# Out:
# TessLightCurve(TICID: 236887394)

# %%
lc.scatter(s=0.1)

# %%
folded_lc

# %%
folded_lc.plot()
