# %%
from lightkurve import search_targetpixelfile

# %%
pixelfile = search_targetpixelfile(8462852, quarter=16).download(quality_bitmask='hardes')
# Out:
# ...
# gzip was not found on your system! You should solve this issue for astroquery.eso to be at its best!
# On POSIX system: make sure gzip is installed and in your path!On Windows: same for 7-zip (http://www.7-zip.org)!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\lightkurve\search.py in _open_downloaded_file(path, **kwargs)
#    1038     try:
# -> 1039         return open(path, **kwargs)
#    1040     except ValueError:
#
# ~\Anaconda3\lib\site-packages\lightkurve\search.py in open(path_or_url, **kwargs)
#    1030         raise ValueError("Not recognized as a Kepler or TESS data product: "
# -> 1031                          "{}".format(path_or_url))
#    1032
#
# ...

# %%
pixels = search_targetpixelfile('kepler-10').download()
# Out:
# C:\Users\jerobado\Anaconda3\lib\site-packages\lightkurve\search.py:233: LightkurveWarning: Warning: 16 files available to download. Only the first file has been downloaded. Please use `download_all()` or specify additional criteria (e.g. quarter, campaign, or sector) to limit your search.
#   LightkurveWarning)

# %%
pixels.plot()

# %%
print(type(pixels))
# Out:
# <class 'lightkurve.targetpixelfile.KeplerTargetPixelFile'>

# %%
lightcurve = pixels.to_lightcurve()
lightcurve.plot()

# %%
exoplanet = lightcurve.flatten().fold(period=0.838)

# %%
pixelfile = search_targetpixelfile(8462852, quarter=16).download(quality_bitmask='hardest')
# Out:
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\lightkurve\search.py in _open_downloaded_file(path, **kwargs)
#    1038     try:
# -> 1039         return open(path, **kwargs)
#    1040     except ValueError:
#
# ~\Anaconda3\lib\site-packages\lightkurve\search.py in open(path_or_url, **kwargs)
#    1030         raise ValueError("Not recognized as a Kepler or TESS data product: "
# -> 1031                          "{}".format(path_or_url))
#    1032
#
# ValueError: Not recognized as a Kepler or TESS data product: C:\Users\jerobado\.lightkurve-cache/mastDownload\Kepler\kplr008462852_lc_Q111111111111111111\kplr008462852-2013098041711_lpd-targ.fits.gz
#
# During handling of the above exception, another exception occurred:
#
# SearchError                               Traceback (most recent call last)
# <ipython-input-10-1ec2850d7cd7> in <module>
# ...

# %%
exoplanet.plot()

# %%
pixelfile = search_targetpixelfile('8462852', quarter=16).download(quality_bitmask='hardest')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\lightkurve\search.py in _open_downloaded_file(path, **kwargs)
#    1038     try:
# -> 1039         return open(path, **kwargs)
#    1040     except ValueError:
#
# ~\Anaconda3\lib\site-packages\lightkurve\search.py in open(path_or_url, **kwargs)
#    1030         raise ValueError("Not recognized as a Kepler or TESS data product: "
# -> 1031                          "{}".format(path_or_url))
#    1032
#
# ValueError: Not recognized as a Kepler or TESS data product: C:\Users\jerobado\.lightkurve-cache/mastDownload\Kepler\kplr008462852_lc_Q111111111111111111\kplr008462852-2013098041711_lpd-targ.fits.gz
#
# During handling of the above exception, another exception occurred:
#
# SearchError                               Traceback (most recent call last)
# <ipython-input-11-3276f09ff756> in <module>
# ...

# %%
pixelfile = search_targetpixelfile('8462852').download()
# Out:
# C:\Users\jerobado\Anaconda3\lib\site-packages\lightkurve\search.py:233: LightkurveWarning: Warning: 18 files available to download. Only the first file has been downloaded. Please use `download_all()` or specify additional criteria (e.g. quarter, campaign, or sector) to limit your search.
#   LightkurveWarning)

# %%
pixelfile = search_targetpixelfile('8462852', quarter=16).download()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\lightkurve\search.py in _open_downloaded_file(path, **kwargs)
#    1038     try:
# -> 1039         return open(path, **kwargs)
#    1040     except ValueError:
#
# ~\Anaconda3\lib\site-packages\lightkurve\search.py in open(path_or_url, **kwargs)
#    1030         raise ValueError("Not recognized as a Kepler or TESS data product: "
# -> 1031                          "{}".format(path_or_url))
#    1032
#
# ValueError: Not recognized as a Kepler or TESS data product: C:\Users\jerobado\.lightkurve-cache/mastDownload\Kepler\kplr008462852_lc_Q111111111111111111\kplr008462852-2013098041711_lpd-targ.fits.gz
#
# During handling of the above exception, another exception occurred:
#
# SearchError                               Traceback (most recent call last)
# <ipython-input-13-7303fa0a0e15> in <module>
# ...

# %%
pixelfile = search_targetpixelfile(8462852, quarter=16).download()
# Out:
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\lightkurve\search.py in _open_downloaded_file(path, **kwargs)
#    1038     try:
# -> 1039         return open(path, **kwargs)
#    1040     except ValueError:
#
# ~\Anaconda3\lib\site-packages\lightkurve\search.py in open(path_or_url, **kwargs)
#    1030         raise ValueError("Not recognized as a Kepler or TESS data product: "
# -> 1031                          "{}".format(path_or_url))
#    1032
#
# ValueError: Not recognized as a Kepler or TESS data product: C:\Users\jerobado\.lightkurve-cache/mastDownload\Kepler\kplr008462852_lc_Q111111111111111111\kplr008462852-2013098041711_lpd-targ.fits.gz
#
# During handling of the above exception, another exception occurred:
#
# SearchError                               Traceback (most recent call last)
# <ipython-input-14-8d2871f4e07a> in <module>
# ...

# %%
pixelfile = search_targetpixelfile('KIC8462852', quarter=16).download()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\lightkurve\search.py in _open_downloaded_file(path, **kwargs)
#    1038     try:
# -> 1039         return open(path, **kwargs)
#    1040     except ValueError:
#
# ~\Anaconda3\lib\site-packages\lightkurve\search.py in open(path_or_url, **kwargs)
#    1030         raise ValueError("Not recognized as a Kepler or TESS data product: "
# -> 1031                          "{}".format(path_or_url))
#    1032
#
# ValueError: Not recognized as a Kepler or TESS data product: C:\Users\jerobado\.lightkurve-cache/mastDownload\Kepler\kplr008462852_lc_Q111111111111111111\kplr008462852-2013098041711_lpd-targ.fits.gz
#
# During handling of the above exception, another exception occurred:
#
# SearchError                               Traceback (most recent call last)
# <ipython-input-15-414605ba8b98> in <module>
# ...

# %%
pixelfile.plot()

# %%
search_targetpixelfile
# Out:
# <function lightkurve.search.search_targetpixelfile(target, radius=None, cadence='long', mission=('Kepler', 'K2', 'TESS'), quarter=None, month=None, campaign=None, sector=None, limit=None)>

# %%
from lightkurve import KeplerTargetPixelFile

# %%
KeplerTargetPixelFile
# Out:
# lightkurve.targetpixelfile.KeplerTargetPixelFile

# %%
tpf = search_targetpixelfile('KIC 6922244', quarter=4).download()

# %%
tpf
# Out:
# KeplerTargetPixelFile Object (ID: 6922244)

# %%
tpf.mission
# Out:
# 'Kepler'

# %%
dir(tpf)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_aperture_photometry',
#  '_estimate_centroids_via_moments',
#  '_estimate_centroids_via_quadratic',
#  '_hdu',
#  '_parse_aperture_mask',
#  'astropy_time',
#  'cadenceno',
#  'campaign',
#  'channel',
#  'column',
#  'create_threshold_mask',
#  'cutout',
#  'dec',
#  'estimate_centroids',
#  'extract_aperture_photometry',
#  'extract_prf_photometry',
#  'flux',
#  'flux_bkg',
#  'flux_bkg_err',
#  'flux_err',
#  'from_fits_images',
#  'get_bkg_lightcurve',
#  'get_coordinates',
#  'get_keyword',
#  'get_model',
#  'get_prf_model',
#  'hdu',
# ...

# %%
tpf.ra
tpf.dec
# Out:
# 42.45108

# %%
tpf.ra
# Out:
# 281.28812

# %%
tpf.dec
# Out:
# 42.45108

# %%
tpf.time
# Out:
# array([352.37632485, 352.39675805, 352.43762445, ..., 442.16263546,
#        442.18306983, 442.2035041 ])

# %%
tpf.astropy_time.iso
# Out:
# array(['2009-12-19 21:01:54.467', '2009-12-19 21:31:19.895',
#        '2009-12-19 22:30:10.752', ..., '2010-03-19 15:54:11.704',
#        '2010-03-19 16:23:37.233', '2010-03-19 16:53:02.754'], dtype='<U23')

# %%
tpf.flux.shape
# Out:
# (4116, 5, 5)

# %%
tpf.plot()

# %%
lightcurve = tpf.to_lightcurve()
lightcurve.flatten().remove_outliers().plot().errorbar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-336973a1cee0> in <module>
#       1 lightcurve = tpf.to_lightcurve()
# ----> 2 lightcurve.flatten().remove_outliers().plot().errorbar()
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# TypeError: errorbar() missing 2 required positional arguments: 'x' and 'y'

# %%
tpf
# Out:
# KeplerTargetPixelFile Object (ID: 6922244)

# %%
lc = tpf.to_lightcurve(aperture_mask=tpf.pipeline_mask)

# %%
dir(lc)
# Out:
# ['__add__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__radd__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__sizeof__',
#  '__slotnames__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '_create_plot',
#  '_flux_unit',
#  '_validate_array',
#  '_validate_time',
#  'append',
#  'astropy_time',
#  'bin',
#  'cadenceno',
#  'campaign',
#  'centroid_col',
#  'centroid_row',
#  'channel',
#  'copy',
#  'dec',
#  'errorbar',
#  'estimate_cdpp',
#  'fill_gaps',
#  'flatten',
#  'flux',
#  'flux_err',
#  'flux_quantity',
#  'flux_unit',
#  'fold',
# ...

# %%
lc.plot()

# %%
flat_lc = lc.flatten(window_length=401)
flat_lc.plot()

# %%
folder_lc = flat_lc.fold(period=3.5225)
folder_lc.plot()

# %%
binned_lc = folder_lc.bin(binsize=10)
binned_lc.plot()

# %%
from lightkurve import search_lightcurvefile
lcf = search_lightcurvefile('KIC 6922244', quarter=4).download()

# %%
lcf.plot()

# %%
pdcsap = lcf.PDCSAP_FLUX

# %%
pdcsap.plot()

# %%
from lightkurve import search_lightcurvefile
lc = search_lightcurvefile('KIC 10264202', quarter=10).download().PDCSAP_FLUX.remove_nans()

# %%
pdcsap.scatter()

# %%
lc.scatter()

# %%
pg = lc.to_periodogram(oversample_factor=1)

# %%
pg.plot()

# %%
pg.plot(view='period', scale='log')

# %%
lc.fold(pg.period_at_max_power).scatter()

# %%
lc.fold(4 * pg.period_at_max_power).scatter()

# %%
import astropy.units as u
pg = lc.to_periodogram(minimum_period=0.9*u.day, maximum_period=1.2*u.day, oversample_factor=10)
pg.period_at_max_power
# Out:
# <Quantity 1.03509717 d>

# %%
lc.fold(pg.period_at_max_power).scatter()
